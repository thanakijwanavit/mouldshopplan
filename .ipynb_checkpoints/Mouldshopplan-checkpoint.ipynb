# %%
import requests

# %%
#get data from google sheets
def getdata(url='https://docs.google.com/spreadsheets/d/e/2PACX-1vQUZvwS_Uue7j4zfhZcw1AIujz_fZvAh7RSRnmozQJmE6j69-djrGYuZWcGTwGa446b6CtU-k-I3rkh/pub?gid=1649651434&single=true&output=csv'):
    t=requests.get(url)
    t.encoding='utf-8'
    infostring=t.text
    return infostring
##parse google sheet data into array r
def parseIntoArray(string):
    string = infostring.replace('\r','cp874').split('\n')
    s = []
    for i in range(0,len(r)):
        s.append(r[i].split(','))
    return s
def testGetdata():
    print(parseIntoArray(getdata()))
testGetdata()
# Out:
# [['--', '', '', '', '', '', '', '', '', '', '', '', '', 'cp874'], ['', '', '', '', '', '', '', '', 'ต้องเขียน format เหมือนช่องขาว', '', '', '', '', 'cp874'], ['status', 'Timestamp', 'Email Address', 'Mould Name', 'mould number', 'product', 'Available to start date', 'submission date', 'Available finish date', 'required finished date', 'problems with the mould', 'Staff1 ID', 'Staff2 ID', 'Notecp874'], ['finished', '1/7/2018 18:09:25', 'kornpongs@hatari.co.th', 'ขาเสา S18M1', 'IA-078', 'ขาเสา S18M1', '9-Jan-2018', '25-Dec-2017', '27-Jan-2018', '15-Jan-2018', '"Flash parting line ', ' Flash Boss', ' rust on surface"', 'D ประวิทย์', '', '"ช่างประวิทย์ insert cavaty มีรอยร้าว กำลังเชื่อมอยู่ครับ ส่งเชื่อมข้างนอก ', '18/1/2018 เริ่มขัดเงาพิมพ์', ' 20-Jan-2018 ส่งทดลองฉีดเช็คสเปคก่อน  22/1/2018 นำพิมพ์กลับมาขัดเงา"cp874'], ['finished', '1/8/2018 9:32:48', 'kornpongs@hatari.co.th', '"กะโหลกหลัง(back cover) 18"""', 'IE-045', '"กะโหลกหลัง(back cover) 18"""', '8-Jan-2018', '6-Jan-2018', '10-Jan-2018', '13-Jan-2018', 'Flash parting line', 'G ทวี', '', '"ช่างทวี เชื่อมเรเซอร์', ' ตกแต่งฟิตพิมพ์"cp874'], ['finished', '1/8/2018 10:16:47', 'kornpongs@hatari.co.th', 'ตัวรัดสายไฟ (แบน) ', 'IR-168', 'อะไหล่ทุกรุ่น(Spare parts all model)', '6-Jan-2018', '3-Jan-2018', '13-Feb-2018', '15-Jan-2018', 'รอ insert ใหม่ถึงจะส่งซ่อมอีกครั้ง( wait new insert finish repair again)', 'I จิระวัฒน์', '', 'ช่างจิระวัฒน์ นำแม่พิมพ์มาใส่ฟิต Insert  เข้ากับแม่พิมพฝั่ง Core ฟิตอย่างเดียว เสร็จวันที่ 08/01/2018 ประกอบพิมพ์ส่งคืน รอทำInsert ให้เสร็จพร้อมชุบแช็ง ส่งชุบแข็งวันที่ 27/01/2018cp874'], ['finished', '1/8/2018 10:25:12', 'kornpongs@hatari.co.th', '"ขอบตะแกรง 16""( Grill ring 16"")\t"', 'IF-022', '"อะไหล่รุ่น 16"" (spare part model 16"")"', '22-Dec-2017', '25-Nov-2017', '12-Jan-2018', '5-Jan-2018', 'ซ่อมเสร็จ วันที่ 5/1/18 ผล NG ซ่อมอีกครั้ง (finish repair on 5/1 result NG and repair again)', 'G ทวี', '', '"ช่างทวี สปาร์คร่องเพิ่ม 2 ตำแหน่ง', ' ฟิตแม่พิมพ์ CNC ตัว PP"cp874'], ['finished', '1/8/2018 10:32:58', 'kornpongs@hatari.co.th', 'ใบพัดล่าง TW20 สีดำ', 'IG-041', '"อะไหล่รุ่น TW20', 'AC Classic(Spare part TW20', 'AC Classic)"', '2-Jan-2018', '4-Jan-2018', '6-Jan-2018', '6-Jan-2018', 'Flash parting line and runner stick cavity', 'C อำนวย', '', 'ช่างอำนวย แก้ไขเพิ่มตัวดันทางฉีด และฟิตแม่พิมพ์cp874'], ['finished', '1/8/2018 10:39:29', 'kornpongs@hatari.co.th', 'แผ่นปิดฐานล่าง IP22M5 (A17)', 'IV-044', 'แผ่นปิดฐานล่าง IP22M5 (A17)(Base cover bottom IP22M5 A17)', '5-Jan-2018', '28-Dec-2017', '8-Jan-2018', '15-Jan-2018', 'Runner have flash and stick cavity', 'F อนุสรณ์', '', 'ช่างอนุสรณ์ แก้ไข Runner เป็นครึ้งวงกลม ขนาด 5 mm. และฟิตแม่พิมพ์ ทดลองฉีดวันที่ 10/01/2018cp874'], ['finished', '1/8/2018 17:08:39', 'kornpongs@hatari.co.th', '"ตะแกรงหน้าพัดลมระบายอากาศ 6"""', 'IL-067', ' VW15M4(G)', '5-Jan-2018', '25-Dec-2017', '10-Jan-2018', '15-Jan-2018', 'part stick ejector core cannot use robot ans check cooling  system', 'D ประวิทย์', '', '"ช่างประวิทย์ ฟิตพิมพ์ตรงเขี้ยวล็อค', ' ขัดเงาแม่พิมพ์ ', ' เช็ค Cooling"cp874'], ['finished', '1/9/2018 17:11:36', 'kornpongs@hatari.co.th', ' ขาเสา S16 R2', '  IG-041', 'S16 R2', '11-Jan-2018', '10-Jan-2018', '11-Jan-2018', '17-Jan-2018', 'Runner stick sprue bush (ทางฉีดติด sprue bush)and surface have scratch(พื้นผิวเป็นรอย)', 'D ประวิทย์', '', 'ช่างประวิทย์ EDM Sprue bush และขัดเงาแม่พิมพ์ ตรงที่เป็นรอยcp874'], ['finished', '1/11/2018 15:33:39', 'kornpongs@hatari.co.th', 'ฝาครอบบน ACTURBO', 'IL-076', 'AC TURBO', '10-Jan-2018', '1/10/2018', '11-Jan-2018', '1/15/2018', 'Sink mark area boss (บุบยุบด้านหน้า บริเวณ ขา Boss)', 'H บุญถึง', '', 'ช่างบุญถึง เปลี่ยนปลอกกระทุ้ง OD 7 ID 4 mm. จำนวน 6 อัน และเปลี่ยนเข็มกระทุ้ง 4 mm. cp874'], ['finished', '1/11/2018 16:05:19', 'kornpongs@hatari.co.th', '  ขายึดมอเตอร์ AC TURBO', 'IA-095', 'AC TURBO', '12-Jan-2018', '1/11/2018', '16-Jan-2018', '1/15/2018', 'insert slide deform (ก้อนไสลด์เสียรูป)', 'D ประวิทย์', '', 'ช่างประวิทย์ CNC Insert slide ให้กลมแล้วเชื่ื่อมเรเซอร์ รอยเชื่อมแตกไม่เกาะกั ...
